# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Excel and show sheet

# %%
df = pd.read_excel("used_price.xlsx")

# %%
df.head(10)
# Out:
#                   Computer  Price    Using Period         System  \
# 0  Alienware M14X R2\n2012  12000       2012-2018       Windows7
# 1       ThinkPad E14\n2016   5000       2016-2018       Windows7
# 2     Macbook Pro 15\n2017  26000        2017-Now          MacOS
# 3     Macbook Air M1\n2021   8000   2021.8-2022.5          MacOS
# 4        ThinkPad X1\n2022  16000  2022.6-2022.11  Linux(Ubuntu)
# 5  ThinkPad P15 Gen3\n2022  22000     2022.12-Now  Linux(Ubuntu)
#
#          Function
# 0      Game|Study
# 1            Work
# 2           Study
# 3  Work and Study
# 4            Work
# 5            Work

# %% [markdown]
# # Price plot

# %%
# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]+300, y[i], ha = 'center')

# %%
fig = plt.figure(dpi=800)
ax = fig.add_axes([0,0,1,1])
ax.bar(df['Computer'],df["Price"],color=['red','orangered','silver','dodgerblue','green','blue'])
plt.xlabel('Computer series')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Price (DKK)')
plt.title('Compare different price of my used computers')
# Get average price line
plt.axhline(y=np.mean(df['Price']), color='red', linestyle='--',linewidth=1)
plt.legend(["Average price", "Computer price"])
addlabels(df['Computer'],df["Price"])
plt.show()
